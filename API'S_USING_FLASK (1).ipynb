# %%
## table create kiye hai

from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
## data base la connect honya sathi engine use kela, import 
metadata = MetaData()

# Define the cartoons table
cartoons = Table(
    'cartoons', metadata,
    Column('id', Integer, primary_key=True),
    Column('title', String(100)),
    Column('description', String(255)),
    Column('rating', Float)
)

# Create the table in the database if it doesn't exist
metadata.create_all(engine)

@app.route('/', methods=['GET', 'POST'])
def home():
    if request.method == 'POST':
        data = request.json
        title = data.get('title')
        description = data.get('description')
        rating = data.get('rating')

        # Insert data into the cartoons table
        with engine.connect() as conn:
            conn.execute(cartoons.insert().values(title=title, description=description, rating=rating))

        return jsonify({'message': 'Data inserted successfully'})
    else:
        return "Cartoons table created successfully!"

if __name__ == '__main__':
    app.run(debug=False)

# %%
### data ko add kiye table mai

from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData()

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

@app.route('/', methods=['POST'])
def add_cartoon():
    data = request.json
    title = data.get('title')
    description = data.get('description')
    rating = data.get('rating')

    # Insert data into the cartoons table
    with engine.connect() as conn:
        conn.execute(cartoons.insert().values(title=title, description=description, rating=rating))

    return jsonify({'message': 'Data inserted successfully'})

if __name__ == '__main__':
    app.run(debug=False)

# %%
## kisis table mai mujhe bkuch update karna hai matlab kisis column mai to mai update iuse kar saki hu


from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData()

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

@app.route('/update_cartoon/<int:id>', methods=['PUT'])
def update_cartoon(id):
    data = request.json
    title = data.get('title')
    description = data.get('description')
    rating = data.get('rating')

    # Update data in the cartoons table
    with engine.connect() as conn:
        update_stmt = cartoons.update().where(cartoons.c.id == 11).values(title=title, description=description, rating=rating)
        conn.execute(update_stmt)

    return jsonify({'message': f'Cartoon with ID {11} updated successfully'})

if __name__ == '__main__':
    app.run(debug=False)

# %%
## delete use karke me maise table mai se kuch row delete kar diye


from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData()

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

@app.route('/delete_cartoon/<int:id>', methods=['DELETE'])
def delete_cartoon(id):
    # Delete data from the cartoons table
    with engine.connect() as conn:
        delete_stmt = cartoons.delete().where(cartoons.c.id == 7)
        conn.execute(delete_stmt)

    return jsonify({'message': f'Cartoon with ID {7} deleted successfully'})

if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [16/May/2024 21:00:53] "DELETE /delete_cartoon/21 HTTP/1.1" 200 -
# 127.0.0.1 - - [17/May/2024 11:00:16] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [17/May/2024 11:00:16] "GET /favicon.ico HTTP/1.1" 404 -

# %%
## column add kiye table ai category

from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData(bind=engine)

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

# Add a new column to the cartoons table
new_column = Column('category', String(50))
new_column.create(cartoons)

@app.route('/', methods=['GET', 'POST'])
def home():
    if request.method == 'POST':
        data = request.json
        title = data.get('title')
        description = data.get('description')
        rating = data.get('rating')
        category = data.get('category')  # Extracting the new column data

        # Insert data into the cartoons table
        with engine.connect() as conn:
            conn.execute(cartoons.insert().values(title=title, description=description, rating=rating, category=category))

        return jsonify({'message': 'Data inserted successfully'})
    else:
        return "Cartoons table created successfully!"

if __name__ == '__main__':
    app.run(debug=False)

# %%
##### maine ye code use karke mere table mai or ek column add kiye hai jo ki vo categorry, catogyri1  hai.



from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData(bind=engine)

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

# Add a new column 'category' to the cartoons table if it doesn't exist
if not hasattr(cartoons.c, 'category1'):
    with engine.connect() as conn:
        conn.execute("ALTER TABLE cartoons ADD COLUMN category1 VARCHAR(50)")

@app.route('/', methods=['GET', 'POST'])
def home():
    if request.method == 'POST':
        data = request.json
        title = data.get('title')
        description = data.get('description')
        rating = data.get('rating')
        category1 = data.get('category1')

        # Insert data into the cartoons table
        with engine.connect() as conn:
            conn.execute(cartoons.insert().values(title=title, description=description, rating=rating, category1=category1))

        return jsonify({'message': 'Data inserted successfully'})
    else:
        return "Welcome to the Cartoons API!"

if __name__ == '__main__':
    app.run(debug=False)

# %%
## column create kiye hai mane video bolke but yaha pe varchar likha to mera video upload nai ho rha tha,  baki add hua means
## title description, ...


from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData(bind=engine)

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

# Add a new column 'video' to the cartoons table if it doesn't exist
if not hasattr(cartoons.c, 'video'):
    with engine.connect() as conn:
        conn.execute("ALTER TABLE cartoons ADD COLUMN video VARCHAR(225)")

@app.route('/', methods=['POST'])
def add_cartoon():
    title = request.form.get('title')
    description = request.form.get('description')
    rating = request.form.get('rating')
    category = request.form.get('category')
    video = request.form.get('video')

    # Insert data into the cartoons table
    with engine.connect() as conn:
        conn.execute(cartoons.insert().values(title=title, description=description, rating=rating, category=category, video=video))

    return 'Cartoon added successfully!'

if __name__ == '__main__':
    app.run(debug=False)

# %%
### video1 column create kaiye maine or usme video upload kiye 


from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float, LargeBinary

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData(bind=engine)

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

# Add a new column 'video1' to the cartoons table if it doesn't exist
if not hasattr(cartoons.c, 'video1'):
    video_column = Column('video1', LargeBinary)
    with engine.connect() as conn:
        video_column.create(cartoons, bind=conn)

@app.route('/', methods=['POST'])
def add_cartoon():
    title = request.form.get('title')
    description = request.form.get('description')
    rating = request.form.get('rating')
    category = request.form.get('category')
    video = request.files['video1'].read()  # Access the video file and read its content

    # Insert data into the cartoons table
    with engine.connect() as conn:
        conn.execute(cartoons.insert().values(title=title, description=description, rating=rating, category=category, video1=video))

    return 'Cartoon added successfully!'

if __name__ == '__main__':
    app.run(debug=False)

# %%
import pandas as pd
from sqlalchemy import create_engine, MetaData, Table, select

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')

# Reflect the existing cartoons table
metadata = MetaData(bind=engine)
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

# Establish a connection to the database
connection = engine.connect()

# Select all rows from the cartoons table
query = select([cartoons])

# Execute the query and fetch all results into a DataFrame
df = pd.read_sql(query, connection)

# Close the database connection
connection.close()

# Display the DataFrame
df

# %%
###data ko fetch kiye table mai se

from flask import Flask, request, jsonify
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float

app = Flask(__name__)

# Create SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:komal@localhost/patil')
metadata = MetaData(bind=engine)

# Reflect the existing cartoons table
cartoons = Table('cartoons', metadata, autoload=True, autoload_with=engine)

@app.route('/cartoons/<int:id>', methods=['GET'])
def get_cartoon(id):
    # Fetch data for the specified ID from the cartoons table
    query = cartoons.select().where(cartoons.c.id == 12)
    with engine.connect() as conn:
        result = conn.execute(query).fetchone()

    if result:
        # Convert the result to a dictionary for JSON serialization
        cartoon_data = dict(result)
        return jsonify(cartoon_data)
    else:
        return 'Cartoon not found for the specified ID', 404

if __name__ == '__main__':
    app.run(debug=False)
